# %% [markdown]
# # Stemming
#
# It's often (but not always) useful to reduce words to their roots. One reason for doing this may be that word tense or conjugation is not important for your model. It would be useful to combine variations of a word together. Then for models like Naive Bayes where each word is a feature, we can strongly reduce our feature space.
#
# Let's see what this looks like. First, let's tokenize a bit of text from the wikipedia page on data science.

# %%
from nltk.tokenize import wordpunct_tokenize  # for tokenizing our text

# %%
# sample text from wikipedia
import codecs
# another way to open a text file
text = codecs.open('data/sample.txt', "r", "utf-8").read()

word_bag = wordpunct_tokenize(text)
print 'a few tokens:', word_bag[:10]
print 'number of tokens:', len(word_bag)
print 'number of unique tokens:', len(set(word_bag))
# Out:
# a few tokens: [u'Data', u'science', u'From', u'Wikipedia', u',', u'the', u'free', u'encyclopedia', u'Data', u'Science']
# number of tokens: 1684
# number of unique tokens: 665

# %% [markdown]
# Look for common word endings to clip off. Start with the suffix, '-s', '-er', '-ing'. But be careful to only strip these tokens when they appear at the end of the word. Write rules into the function below.

# %%
alabama = 'alabamania'
alabama[:-3]
# Out:
# 'alabama'

# %%
# define a function to stem tokens based on rules.

def stem(tokens):
    '''rules-based stemming of a bunch of tokens'''
    
    new_bag = []
    for token in tokens:
        # define rules here
        if (len(token)>4) & (token[-1] == 's'):  # edit this to test for some condition involving `token`
            new_bag.append(token[:-1]) # append the stemmed token to the bag.
        elif token[-2:] == 'er':
            new_bag.append(token[:-2]) # keep adding more rules in elif statements.
        elif token[-3:] == 'ing':
            new_bag.append(token[:-3])
        elif token[-2:] == 'es':
            new_bag.append(token[:-2])
        elif token[-2:] == 'ed':
            new_bag.append(token[:-2])
        else:  # base case there no stemming is required
            new_bag.append(token)

    return new_bag

stem(word_bag)
# Out:
# [u'Data',
#  u'science',
#  u'From',
#  u'Wikipedia',
#  u',',
#  u'the',
#  u'free',
#  u'encyclopedia',
#  u'Data',
#  u'Science',
#  u'Venn',
#  u'Diagram',
#  u'Data',
#  u'science',
#  u'is',
#  u'the',
#  u'study',
#  u'of',
#  u'the',
#  u'generalizable',
#  u'extraction',
#  u'of',
#  u'knowledge',
#  u'from',
#  u'data',
#  u',[',
#  u'1',
#  u']',
#  u'yet',
#  u'the',
#  u'key',
#  u'word',
#  u'is',
#  u'science',
#  u'.[',
#  u'2',
#  u']',
#  u'It',
#  u'incorporate',
#  u'vary',
#  u'element',
#  u'and',
#  u'build',
#  u'on',
#  u'technique',
#  u'and',
#  u'theorie',
#  u'from',
#  u'many',
#  u'field',
#  u',',
#  u'includ',
#  u'signal',
#  u'process',
#  u',',
#  u'mathematic',
#  u',',
#  u'probability',
#  u'model',
#  u',',
#  u'machine',
#  u'learn',
#  u',',
#  u'statistical',
#  u'learn',
#  u',',
#  u'comput',
#  u'programm',
#  u',',
#  u'data',
#  u'engineer',
#  u',',
#  u'pattern',
#  u'recognition',
#  u'and',
#  u'learn',
#  u',',
#  u'visualization',
#  u',',
#  u'uncertainty',
#  u'model',
#  u',',
#  u'data',
#  u'warehous',
#  u',',
#  u'and',
#  u'high',
#  u'performance',
#  u'comput',
#  u'with',
#  u'the',
#  u'goal',
#  u'of',
#  u'extract',
#  u'mean',
#  u'from',
#  u'data',
#  u'and',
#  u'creat',
#  u'data',
#  u'product',
#  u'.',
#  u'The',
#  u'subject',
#  u'is',
#  u'not',
#  u'restrict',
#  u'to',
#  u'only',
#  u'big',
#  u'data',
#  u',',
#  u'although',
#  u'the',
#  u'fact',
#  u'that',
#  u'data',
#  u'is',
#  u'scal',
#  u'up',
#  u'make',
#  u'big',
#  u'data',
#  u'an',
#  u'important',
#  u'aspect',
#  u'of',
#  u'data',
#  u'science',
#  u'.',
#  u'A',
#  u'practition',
#  u'of',
#  u'data',
#  u'science',
#  u'is',
#  u'call',
#  u'a',
#  u'data',
#  u'scientist',
#  u'.',
#  u'Data',
#  u'scientist',
#  u'solve',
#  u'complex',
#  u'data',
#  u'problem',
#  u'through',
#  u'employ',
#  u'deep',
#  u'expertise',
#  u'in',
#  u'some',
#  u'scientific',
#  u'discipline',
#  u'.',
#  u'It',
#  u'is',
#  u'generally',
#  u'expect',
#  u'that',
#  u'data',
#  u'scientist',
#  u'are',
#  u'able',
#  u'to',
#  u'work',
#  u'with',
#  u'variou',
#  u'element',
#  u'of',
#  u'mathematic',
#  u',',
#  u'statistic',
#  u'and',
#  u'comput',
#  u'science',
#  u',',
#  u'although',
#  u'expertise',
#  u'in',
#  u'these',
#  u'subject',
#  u'are',
#  u'not',
#  u'requir',
#  u'.[',
#  u'3',
#  u']',
#  u'Howev',
#  u',',
#  u'a',
#  u'data',
#  u'scientist',
#  u'is',
#  u'most',
#  u'likely',
#  u'to',
#  u'be',
#  u'an',
#  u'expert',
#  u'in',
#  u'only',
#  u'one',
#  u'or',
#  u'two',
#  u'of',
#  u'these',
#  u'discipline',
#  u'and',
#  u'proficient',
#  u'in',
#  u'anoth',
#  u'two',
#  u'or',
#  u'three',
#  u'.',
#  u'Therefore',
#  u'data',
#  u'science',
#  u'is',
#  u'practic',
#  u'as',
#  u'a',
#  u'team',
#  u',',
#  u'where',
#  u'the',
#  u'membership',
#  u'of',
#  u'the',
#  u'team',
#  u'have',
#  u'a',
#  u'variety',
#  u'of',
#  u'expertise',
#  u'.',
#  u'Data',
#  u'scientist',
#  u'use',
#  u'the',
#  u'ability',
#  u'to',
#  u'find',
#  u'and',
#  u'interpret',
#  u'rich',
#  u'data',
#  u'source',
#  u',',
#  u'manage',
#  u'large',
#  u'amount',
#  u'of',
#  u'data',
#  u'despite',
#  u'hardware',
#  u',',
#  u'software',
#  u'and',
#  u'bandwidth',
#  u'constraint',
#  u',',
#  u'merge',
#  u'data',
#  u'source',
#  u'togeth',
#  u',',
#  u'ensure',
#  u'consistency',
#  u'of',
#  u'data',
#  u'-',
#  u'sets',
#  u',',
#  u'create',
#  u'visualization',
#  u'to',
#  u'aid',
#  u'in',
#  u'understand',
#  u'data',
#  u',',
#  u'build',
#  u'mathematical',
#  u'model',
#  u'us',
#  u'the',
#  u'data',
#  u',',
#  u'present',
#  u'and',
#  u'communicate',
#  u'the',
#  u'data',
#  u'insight',
#  u'/',
#  u'finding',
#  u'to',
#  u'specialist',
#  u'and',
#  u'scientist',
#  u'in',
#  u'their',
#  u'team',
#  u'and',
#  u'if',
#  u'requir',
#  u'to',
#  u'a',
#  u'non',
#  u'-',
#  u'expert',
#  u'audience',
#  u'.',
#  u'Data',
#  u'science',
#  u'technique',
#  u'affect',
#  u'research',
#  u'in',
#  u'many',
#  u'domain',
#  u',',
#  u'includ',
#  u'the',
#  u'biological',
#  u'science',
#  u',',
#  u'medical',
#  u'informatic',
#  u',',
#  u'health',
#  u'care',
#  u',',
#  u'social',
#  u'science',
#  u'and',
#  u'the',
#  u'humanitie',
#  u'.',
#  u'It',
#  u'heavily',
#  u'influence',
#  u'economic',
#  u',',
#  u'busines',
#  u'and',
#  u'finance',
#  u'.',
#  u'From',
#  u'the',
#  u'busines',
#  u'perspective',
#  u',',
#  u'data',
#  u'science',
#  u'is',
#  u'an',
#  u'integral',
#  u'part',
#  u'of',
#  u'competitive',
#  u'intelligence',
#  u',',
#  u'a',
#  u'newly',
#  u'emerg',
#  u'field',
#  u'that',
#  u'encompasse',
#  u'a',
#  u'numb',
#  u'of',
#  u'activitie',
#  u',',
#  u'such',
#  u'as',
#  u'data',
#  u'min',
#  u'and',
#  u'data',
#  u'analysi',
#  u'.[',
#  u'4',
#  u']',
#  u'Content',
#  u'1',
#  u'History',
#  u'2',
#  u'Domain',
#  u'Specific',
#  u'Interest',
#  u'3',
#  u'Criticism',
#  u'4',
#  u'Research',
#  u'Area',
#  u'4',
#  u'.',
#  u'1',
#  u'Security',
#  u'Data',
#  u'Science',
#  u'4',
#  u'.',
#  u'2',
#  u'Clinical',
#  u'Data',
#  u'Science',
#  u'5',
#  u'Conference',
#  u'6',
#  u'Furth',
#  u'read',
#  u'7',
#  u'Reference',
#  u'History',
#  u'The',
#  u'term',
#  u'"',
#  u'data',
#  u'science',
#  u'"',
#  u'(',
#  u'originally',
#  u'us',
#  u'interchangeably',
#  u'with',
#  u'"',
#  u'datalogy',
#  u'")',
#  u'has',
#  u'exist',
#  u'for',
#  u'ov',
#  u'thirty',
#  u'year',
#  u'and',
#  u'was',
#  u'us',
#  u'initially',
#  u'as',
#  u'a',
#  u'substitute',
#  u'for',
#  u'comput',
#  u'science',
#  u'by',
#  u'Pet',
#  u'Naur',
#  u'in',
#  u'1960',
#  u'.',
#  u'In',
#  u'1974',
#  u',',
#  u'Naur',
#  u'publish',
#  u'Concise',
#  u'Survey',
#  u'of',
#  u'Comput',
#  u'Method',
#  u',',
#  u'which',
#  u'freely',
#  u'us',
#  u'the',
#  u'term',
#  u'data',
#  u'science',
#  u'in',
#  u'its',
#  u'survey',
#  u'of',
#  u'the',
#  u'contemporary',
#  u'data',
#  u'process',
#  u'method',
#  u'that',
#  u'are',
#  u'us',
#  u'in',
#  u'a',
#  u'wide',
#  u'range',
#  u'of',
#  u'application',
#  u'.',
#  u'In',
#  u'1996',
#  u',',
#  u'member',
#  u'of',
#  u'the',
#  u'International',
#  u'Federation',
#  u'of',
#  u'Classification',
#  u'Societie',
#  u'(',
#  u'IFCS',
#  u')',
#  u'met',
#  u'in',
#  u'Tokyo',
#  u'for',
#  u'their',
#  u'biennial',
#  u'conference',
#  u'.',
#  u'Here',
#  u',',
#  u'for',
#  u'the',
#  u'first',
#  u'time',
#  u',',
#  u'the',
#  u'term',
#  u'data',
#  u'science',
#  u'is',
#  u'includ',
#  u'in',
#  u'the',
#  u'title',
#  u'of',
#  u'the',
#  u'conference',
#  u'("',
#  u'Data',
#  u'Science',
#  u',',
#  u'classification',
#  u',',
#  u'and',
#  u'relat',
#  u'method',
#  u'").',
#  u'On',
#  u'10',
#  u'Novemb',
#  u'1997',
#  u',',
#  u'C',
#  u'.',
#  u'F',
#  u'.',
#  u'Jeff',
#  u'Wu',
#  u'gave',
#  u'his',
#  u'inaugural',
#  u'lecture',
#  u'entitl',
#  u'"',
#  u'Statistic',
#  u'=',
#  u'Data',
#  u'Science',
#  u'?"',
#  u'in',
#  u'honor',
#  u'of',
#  u'his',
#  u'appointment',
#  u'to',
#  u'the',
#  u'H',
#  u'.',
#  u'C',
#  u'.',
#  u'Carv',
#  u'Collegiate',
#  u'Professorship',
#  u'in',
#  u'Statistic',
#  u'at',
#  u'the',
#  u'University',
#  u'of',
#  u'Michigan',
#  u'.[',
#  u'5',
#  u']',
#  u'In',
#  u'this',
#  u'lecture',
#  u',',
#  u'he',
#  u'first',
#  u'focus',
#  u'on',
#  u'the',
#  u'identity',
#  u'of',
#  u'statistic',
#  u'in',
#  u'science',
#  u'.',
#  u'He',
#  u'then',
#  u'characteriz',
#  u'statistical',
#  u'work',
#  u'as',
#  u'data',
#  u'collection',
#  u',',
#  u'data',
#  u'model',
#  u'and',
#  u'analysi',
#  u',',
#  u'and',
#  u'problem',
#  u'solv',
#  u'and',
#  u'decision',
#  u'mak',
#  u'.',
#  u'In',
#  u'conclusion',
#  u',',
#  u'he',
#  u'propos',
#  u'that',
#  u'statistic',
#  u'be',
#  u'renam',
#  u'data',
#  u'science',
#  u'and',
#  u'statistician',
#  u'data',
#  u'scientist',
#  u'.[',
#  u'5',
#  u']',
#  u'Lat',
#  u',',
#  u'he',
#  u'present',
#  u'his',
#  u'lecture',
#  u'entitl',
#  u'"',
#  u'Statistic',
#  u'=',
#  u'Data',
#  u'Science',
#  u'?"',
#  u'as',
#  u'the',
#  u'first',
#  u'of',
#  u'his',
#  u'1998',
#  u'P',
#  u'.',
#  u'C',
#  u'.',
#  u'Mahalanobi',
#  u'Memorial',
#  u'Lecture',
#  u'.[',
#  u'6',
#  u']',
#  u'These',
#  u'lecture',
#  u'honor',
#  u'Prasanta',
#  u'Chandra',
#  u'Mahalanobi',
#  u',',
#  u'an',
#  u'Indian',
#  u'scientist',
#  u'and',
#  u'statistician',
#  u'and',
#  u'found',
#  u'of',
#  u'the',
#  u'Indian',
#  u'Statistical',
#  u'Institute',
#  u'.',
#  u'In',
#  u'2001',
#  u',',
#  u'William',
#  u'S',
#  u'.',
#  u'Cleveland',
#  u'introduc',
#  u'the',
#  u'notion',
#  u'of',
#  u'data',
#  u'science',
#  u'as',
#  u'an',
#  u'independent',
#  u'discipline',
#  u',',
#  u'extend',
#  u'the',
#  u'field',
#  u'of',
#  u'statistic',
#  u'to',
#  u'incorporate',
#  u'"',
#  u'advance',
#  u'in',
#  u'comput',
#  u'with',
#  u'data',
#  u'"',
#  u'in',
#  u'his',
#  u'article',
#  u'"',
#  u'Data',
#  u'Science',
#  u':',
#  u'An',
#  u'Action',
#  u'Plan',
#  u'for',
#  u'Expand',
#  u'the',
#  u'Technical',
#  u'Area',
#  u'of',
#  u'the',
#  u'Field',
#  u'of',
#  u'Statistic',
#  u',"',
#  u'which',
#  u'was',
#  u'publish',
#  u'in',
#  u'Volume',
#  u'69',
#  u',',
#  u'No',
#  u'.',
#  u'1',
#  u',',
#  u'of',
#  u'the',
#  u'April',
#  u'2001',
#  u'edition',
#  u'of',
#  u'the',
#  u'International',
#  u'Statistical',
#  u'Review',
#  u'/',
#  u'Revue',
#  u'Internationale',
#  u'de',
#  u'Statistique',
#  u'.[',
#  u'7',
#  u']',
#  u'In',
#  u'his',
#  u'report',
#  u',',
#  u'Cleveland',
#  u'establishe',
#  u'six',
#  u'technical',
#  u'area',
#  u'which',
#  u'he',
#  u'believ',
#  u'to',
#  u'encompas',
#  u'the',
#  u'field',
#  u'of',
#  u'data',
#  u'science',
#  u':',
#  u'multidisciplinary',
#  u'investigation',
#  u',',
#  u'model',
#  u'and',
#  u'method',
#  u'for',
#  u'data',
#  u',',
#  u'comput',
#  u'with',
#  u'data',
#  u',',
#  u'pedagogy',
#  u',',
#  u'tool',
#  u'evaluation',
#  u',',
#  u'and',
#  u'theory',
#  u'.',
#  u'In',
#  u'April',
#  u'2002',
#  u',',
#  u'the',
#  u'International',
#  u'Council',
#  u'for',
#  u'Science',
#  u':',
#  u'Committee',
#  u'on',
#  u'Data',
#  u'for',
#  u'Science',
#  u'and',
#  u'Technology',
#  u'(',
#  u'CODATA',
#  u')[',
#  u'8',
#  u']',
#  u'start',
#  u'the',
#  u'Data',
#  u'Science',
#  u'Journal',
#  u',[',
#  u'9',
#  u']',
#  u'a',
#  u'publication',
#  u'focus',
#  u'on',
#  u'issue',
#  u'such',
#  u'as',
#  u'the',
#  u'description',
#  u'of',
#  u'data',
#  u'system',
#  u',',
#  u'their',
#  u'publication',
#  u'on',
#  u'the',
#  u'internet',
#  u',',
#  u'application',
#  u'and',
#  u'legal',
#  u'issue',
#  u'.[',
#  u'10',
#  u']',
#  u'Shortly',
#  u'thereaft',
#  u',',
#  u'in',
#  u'January',
#  u'2003',
#  u',',
#  u'Columbia',
#  u'University',
#  u'began',
#  u'publish',
#  u'The',
#  u'Journal',
#  u'of',
#  u'Data',
#  u'Science',
#  u',[',
#  u'11',
#  u']',
#  u'which',
#  u'provid',
#  u'a',
#  u'platform',
#  u'for',
#  u'all',
#  u'data',
#  u'worker',
#  u'to',
#  u'present',
#  u'their',
#  u'view',
#  u'and',
#  u'exchange',
#  u'idea',
#  u'.',
#  u'The',
#  u'journal',
#  u'was',
#  u'largely',
#  u'devot',
#  u'to',
#  u'the',
#  u'application',
#  u'of',
#  u'statistical',
#  u'method',
#  u'and',
#  u'quantitative',
#  u'research',
#  u'.',
#  u'In',
#  u'2005',
#  u',',
#  u'The',
#  u'National',
#  u'Science',
#  u'Board',
#  u'publish',
#  u'"',
#  u'Long',
#  u'-',
#  u'liv',
#  u'Digital',
#  u'Data',
#  u'Collection',
#  u':',
#  u'Enabl',
#  u'Research',
#  u'and',
#  u'Education',
#  u'in',
#  u'the',
#  u'21st',
#  u'Century',
#  u'"',
#  u'defin',
#  u'data',
#  u'scientist',
#  u'as',
#  u'"',
#  u'the',
#  u'information',
#  u'and',
#  u'comput',
#  u'scientist',
#  u',',
#  u'database',
#  u'and',
#  u'software',
#  u'and',
#  u'programmer',
#  u',',
#  u'disciplinary',
#  u'expert',
#  u',',
#  u'curator',
#  u'and',
#  u'expert',
#  u'annotator',
#  u',',
#  u'librarian',
#  u',',
#  u'archivist',
#  u',',
#  u'and',
#  u'other',
#  u',',
#  u'who',
#  u'are',
#  u'crucial',
#  u'to',
#  u'the',
#  u'successful',
#  u'management',
#  u'of',
#  u'a',
#  u'digital',
#  u'data',
#  u'collection',
#  u'"',
#  u'whose',
#  u'primary',
#  u'activity',
#  u'is',
#  u'to',
#  u'"',
#  u'conduct',
#  u'creative',
#  u'inquiry',
#  ...]

# %%
# Check how well you're doing by running this cell:

print 'initial number of unique tokens:', len(set(word_bag))
print 'stemmed number of unique tokens:', len(set(stem(word_bag)))
# Out:
# initial number of unique tokens: 665
# stemmed number of unique tokens: 633

# %%
# Do we have to refine our rules? Are we stripping away too many letters? Run this cell to see

for token in stem(word_bag):
    print token
# Out:
# Data
# science
# From
# Wikipedia
# ,
# the
# free
# encyclopedia
# Data
# Science
# Venn
# Diagram
# Data
# science
# is
# the
# study
# of
# the
# generalizable
# extraction
# of
# knowledge
# from
# data
# ,[
# 1
# ]
# yet
# the
# key
# word
# is
# science
# .[
# 2
# ]
# It
# incorporate
# vary
# element
# and
# build
# on
# technique
# and
# theorie
# from
# many
# field
# ,
# includ
# signal
# process
# ,
# mathematic
# ,
# probability
# model
# ,
# machine
# learn
# ,
# statistical
# learn
# ,
# comput
# programm
# ,
# data
# engineer
# ,
# pattern
# recognition
# and
# learn
# ,
# visualization
# ,
# uncertainty
# model
# ,
# data
# warehous
# ,
# and
# high
# performance
# comput
# with
# the
# goal
# of
# extract
# mean
# from
# data
# and
# creat
# data
# product
# .
# The
# subject
# is
# not
# restricted
# to
# only
# big
# data
# ,
# although
# the
# fact
# that
# data
# is
# scal
# up
# make
# big
# data
# an
# important
# aspect
# of
# data
# science
# .
# A
# practition
# of
# data
# science
# is
# called
# a
# data
# scientist
# .
# Data
# scientist
# solve
# complex
# data
# problem
# through
# employ
# deep
# expertise
# in
# some
# scientific
# discipline
# .
# It
# is
# generally
# expected
# that
# data
# scientist
# are
# able
# to
# work
# with
# variou
# element
# of
# mathematic
# ,
# statistic
# and
# comput
# science
# ,
# although
# expertise
# in
# these
# subject
# are
# not
# required
# .[
# 3
# ]
# Howev
# ,
# a
# data
# scientist
# is
# most
# likely
# to
# be
# an
# expert
# in
# only
# one
# or
# two
# of
# these
# discipline
# and
# proficient
# in
# anoth
# two
# or
# three
# .
# Therefore
# data
# science
# is
# practiced
# as
# a
# team
# ,
# where
# the
# membership
# of
# the
# team
# have
# a
# variety
# of
# expertise
# .
# Data
# scientist
# use
# the
# ability
# to
# find
# and
# interpret
# rich
# data
# source
# ,
# manage
# large
# amount
# of
# data
# despite
# hardware
# ,
# software
# and
# bandwidth
# constraint
# ,
# merge
# data
# source
# togeth
# ,
# ensure
# consistency
# of
# data
# -
# sets
# ,
# create
# visualization
# to
# aid
# in
# understand
# data
# ,
# build
# mathematical
# model
# us
# the
# data
# ,
# present
# and
# communicate
# the
# data
# insight
# /
# finding
# to
# specialist
# and
# scientist
# in
# their
# team
# and
# if
# required
# to
# a
# non
# -
# expert
# audience
# .
# Data
# science
# technique
# affect
# research
# in
# many
# domain
# ,
# includ
# the
# biological
# science
# ,
# medical
# informatic
# ,
# health
# care
# ,
# social
# science
# and
# the
# humanitie
# .
# It
# heavily
# influence
# economic
# ,
# busines
# and
# finance
# .
# From
# the
# busines
# perspective
# ,
# data
# science
# is
# an
# integral
# part
# of
# competitive
# intelligence
# ,
# a
# newly
# emerg
# field
# that
# encompasse
# a
# numb
# of
# activitie
# ,
# such
# as
# data
# min
# and
# data
# analysi
# .[
# 4
# ]
# Content
# 1
# History
# 2
# Domain
# Specific
# Interest
# 3
# Criticism
# 4
# Research
# Area
# 4
# .
# 1
# Security
# Data
# Science
# 4
# .
# 2
# Clinical
# Data
# Science
# 5
# Conference
# 6
# Furth
# read
# 7
# Reference
# History
# The
# term
# "
# data
# science
# "
# (
# originally
# used
# interchangeably
# with
# "
# datalogy
# ")
# has
# existed
# for
# ov
# thirty
# year
# and
# was
# used
# initially
# as
# a
# substitute
# for
# comput
# science
# by
# Pet
# Naur
# in
# 1960
# .
# In
# 1974
# ,
# Naur
# published
# Concise
# Survey
# of
# Comput
# Method
# ,
# which
# freely
# used
# the
# term
# data
# science
# in
# its
# survey
# of
# the
# contemporary
# data
# process
# method
# that
# are
# used
# in
# a
# wide
# range
# of
# application
# .
# In
# 1996
# ,
# member
# of
# the
# International
# Federation
# of
# Classification
# Societie
# (
# IFCS
# )
# met
# in
# Tokyo
# for
# their
# biennial
# conference
# .
# Here
# ,
# for
# the
# first
# time
# ,
# the
# term
# data
# science
# is
# included
# in
# the
# title
# of
# the
# conference
# ("
# Data
# Science
# ,
# classification
# ,
# and
# related
# method
# ").
# On
# 10
# Novemb
# 1997
# ,
# C
# .
# F
# .
# Jeff
# Wu
# gave
# his
# inaugural
# lecture
# entitled
# "
# Statistic
# =
# Data
# Science
# ?"
# in
# honor
# of
# his
# appointment
# to
# the
# H
# .
# C
# .
# Carv
# Collegiate
# Professorship
# in
# Statistic
# at
# the
# University
# of
# Michigan
# .[
# 5
# ]
# In
# this
# lecture
# ,
# he
# first
# focused
# on
# the
# identity
# of
# statistic
# in
# science
# .
# He
# then
# characterized
# statistical
# work
# as
# data
# collection
# ,
# data
# model
# and
# analysi
# ,
# and
# problem
# solv
# and
# decision
# mak
# .
# In
# conclusion
# ,
# he
# proposed
# that
# statistic
# be
# renamed
# data
# science
# and
# statistician
# data
# scientist
# .[
# 5
# ]
# Lat
# ,
# he
# presented
# his
# lecture
# entitled
# "
# Statistic
# =
# Data
# Science
# ?"
# as
# the
# first
# of
# his
# 1998
# P
# .
# C
# .
# Mahalanobi
# Memorial
# Lecture
# .[
# 6
# ]
# These
# lecture
# honor
# Prasanta
# Chandra
# Mahalanobi
# ,
# an
# Indian
# scientist
# and
# statistician
# and
# found
# of
# the
# Indian
# Statistical
# Institute
# .
# In
# 2001
# ,
# William
# S
# .
# Cleveland
# introduced
# the
# notion
# of
# data
# science
# as
# an
# independent
# discipline
# ,
# extend
# the
# field
# of
# statistic
# to
# incorporate
# "
# advance
# in
# comput
# with
# data
# "
# in
# his
# article
# "
# Data
# Science
# :
# An
# Action
# Plan
# for
# Expand
# the
# Technical
# Area
# of
# the
# Field
# of
# Statistic
# ,"
# which
# was
# published
# in
# Volume
# 69
# ,
# No
# .
# 1
# ,
# of
# the
# April
# 2001
# edition
# of
# the
# International
# Statistical
# Review
# /
# Revue
# Internationale
# de
# Statistique
# .[
# 7
# ]
# In
# his
# report
# ,
# Cleveland
# establishe
# six
# technical
# area
# which
# he
# believed
# to
# encompas
# the
# field
# of
# data
# science
# :
# multidisciplinary
# investigation
# ,
# model
# and
# method
# for
# data
# ,
# comput
# with
# data
# ,
# pedagogy
# ,
# tool
# evaluation
# ,
# and
# theory
# .
# In
# April
# 2002
# ,
# the
# International
# Council
# for
# Science
# :
# Committee
# on
# Data
# for
# Science
# and
# Technology
# (
# CODATA
# )[
# 8
# ]
# started
# the
# Data
# Science
# Journal
# ,[
# 9
# ]
# a
# publication
# focused
# on
# issue
# such
# as
# the
# description
# of
# data
# system
# ,
# their
# publication
# on
# the
# internet
# ,
# application
# and
# legal
# issue
# .[
# 10
# ]
# Shortly
# thereaft
# ,
# in
# January
# 2003
# ,
# Columbia
# University
# began
# publish
# The
# Journal
# of
# Data
# Science
# ,[
# 11
# ]
# which
# provided
# a
# platform
# for
# all
# data
# worker
# to
# present
# their
# view
# and
# exchange
# idea
# .
# The
# journal
# was
# largely
# devoted
# to
# the
# application
# of
# statistical
# method
# and
# quantitative
# research
# .
# In
# 2005
# ,
# The
# National
# Science
# Board
# published
# "
# Long
# -
# lived
# Digital
# Data
# Collection
# :
# Enabl
# Research
# and
# Education
# in
# the
# 21st
# Century
# "
# defin
# data
# scientist
# as
# "
# the
# information
# and
# comput
# scientist
# ,
# database
# and
# software
# and
# programmer
# ,
# disciplinary
# expert
# ,
# curator
# and
# expert
# annotator
# ,
# librarian
# ,
# archivist
# ,
# and
# other
# ,
# who
# are
# crucial
# to
# the
# successful
# management
# of
# a
# digital
# data
# collection
# "
# whose
# primary
# activity
# is
# to
# "
# conduct
# creative
# inquiry
# and
# analysi
# ."[
# 12
# ]
# In
# 2008
# ,
# DJ
# Patil
# and
# Jeff
# Hammerbach
# coined
# the
# term
# "
# data
# scientist
# "
# to
# define
# their
# jobs
# at
# LinkedIn
# and
# Facebook
# ,
# respectively
# .
# In
# 2012
# ,
# the
# first
# Wikipedia
# article
# on
# Data
# Science
# was
# created
# .
# Domain
# Specific
# Interest
# Data
# science
# is
# the
# practice
# of
# deriv
# valuable
# insight
# from
# data
# .
# Data
# science
# is
# emerg
# to
# meet
# the
# challenge
# of
# process
# very
# large
# data
# sets
# i
# .
# e
# .
# "
# Big
# Data
# "
# consist
# of
# structured
# ,
# unstructured
# or
# semi
# -
# structured
# data
# that
# large
# enterprise
# produce
# .
# A
# domain
# at
# cent
# stage
# of
# data
# science
# is
# the
# explosion
# of
# new
# data
# generated
# from
# smart
# device
# ,
# web
# ,
# mobile
# and
# social
# media
# .
# Data
# science
# require
# a
# versatile
# skill
# -
# set
# .
# Many
# practic
# data
# scientist
# commonly
# specialize
# in
# specific
# domain
# such
# as
# the
# field
# of
# market
# ,
# medical
# ,
# security
# ,
# fraud
# and
# finance
# .
# Howev
# ,
# data
# scientist
# rely
# heavily
# upon
# element
# of
# signal
# process
# ,
# statistic
# ,
# machine
# learn
# ,
# text
# retrieval
# and
# natural
# language
# process
# to
# analyze
# data
# and
# interpret
# result
# .
# Criticism
# Although
# use
# of
# the
# term
# data
# science
# has
# exploded
# in
# busines
# environment
# ,
# many
# academic
# and
# journalist
# see
# no
# distinction
# between
# data
# science
# and
# statistic
# .
# Writ
# in
# Forbe
# ,
# Gil
# Pres
# argue
# that
# data
# science
# is
# a
# buzzword
# without
# a
# clear
# definition
# and
# has
# simply
# replaced
# “
# busines
# analytic
# ”
# in
# context
# such
# as
# graduate
# degree
# program
# .[
# 13
# ]
# In
# the
# question
# -
# and
# -
# answ
# section
# of
# his
# keynote
# addres
# at
# the
# Joint
# Statistical
# Meeting
# of
# American
# Statistical
# Association
# ,
# noted
# applied
# statistician
# Nate
# Silv
# said
# ,
# “
# I
# think
# data
# -
# scientist
# is
# a
# sexed
# up
# term
# for
# a
# statistician
# ....
# Statistic
# is
# a
# branch
# of
# science
# .
# Data
# scientist
# is
# slightly
# redundant
# in
# some
# way
# and
# people
# shouldn
# ’
# t
# berate
# the
# term
# statistician
# .”[
# 14
# ]
# Research
# Area
# As
# an
# interdisciplinary
# subject
# ,
# data
# science
# draw
# scientific
# inquiry
# from
# a
# broad
# range
# of
# academic
# subject
# area
# ,
# mostly
# related
# to
# the
# hard
# science
# .
# Some
# area
# of
# research
# are
# :
# Cloud
# comput
# Database
# and
# information
# integration
# Signal
# Process
# Learn
# ,
# natural
# language
# process
# and
# information
# extraction
# Comput
# vision
# Information
# retrieval
# and
# web
# information
# acces
# Knowledge
# discovery
# in
# social
# and
# information
# network
# Security
# Data
# Science
# Data
# science
# has
# a
# long
# and
# rich
# history
# in
# security
# and
# fraud
# monitor
# reference
# needed
# .
# Security
# data
# science
# is
# focused
# on
# advanc
# information
# security
# through
# practical
# application
# of
# exploratory
# data
# analysi
# ,
# statistic
# ,
# machine
# learn
# and
# data
# visualization
# .
# Although
# the
# tool
# and
# technique
# are
# no
# different
# that
# those
# used
# in
# data
# science
# in
# any
# data
# domain
# ,
# this
# group
# has
# a
# micro
# -
# focu
# on
# reduc
# risk
# ,
# identify
# fraud
# or
# maliciou
# insider
# us
# data
# science
# .
# The
# information
# security
# and
# fraud
# prevention
# industry
# have
# been
# evolv
# security
# data
# science
# in
# ord
# to
# tackle
# the
# challenge
# of
# manag
# and
# gain
# insight
# from
# huge
# stream
# of
# log
# data
# ,
# discov
# insid
# threat
# and
# prevent
# fraud
# .
# Data
# science
# companie
# like
# Feedzai
# [
# 15
# ]
# use
# a
# mix
# of
# big
# data
# ,
# machine
# learn
# ,
# and
# human
# intelligence
# to
# identify
# fraudulent
# payment
# transaction
# .
# Security
# data
# science
# is
# "
# data
# driven
# ,
# "
# mean
# that
# new
# insight
# and
# value
# come
# directly
# from
# data
# .[
# 16
# ]
# Clinical
# Data
# Science
# Data
# science
# has
# alway
# been
# prominent
# in
# the
# field
# of
# clinical
# trial
# .
# Timely
# insight
# into
# clinical
# data
# provide
# answer
# to
# medical
# question
# document
# the
# safety
# and
# efficacy
# of
# novel
# and
# exist
# therapeutic
# compound
# .
# With
# large
# and
# complex
# data
# ,
# clinical
# data
# scientist
# have
# been
# produc
# statistical
# analyse
# of
# clinical
# trial
# for
# market
# application
# since
# clinical
# development
# has
# been
# required
# .
# In
# the
# early
# 2000
# ,
# the
# clinical
# data
# scientist
# evolved
# from
# a
# role
# of
# a
# consultant
# to
# statistician
# to
# a
# strategic
# one
# .
# Now
# the
# clinical
# data
# scientist
# assist
# in
# the
# plann
# ,
# collection
# ,
# transformation
# ,
# analysi
# and
# report
# of
# clinical
# trial
# data
# and
# communication
# of
# their
# result
# .
# These
# scientist
# are
# crucial
# to
# the
# determination
# of
# safety
# and
# efficacy
# of
# novel
# therapeutic
# compound
# .

# %% [markdown]
# Feel free to add more rules and see how much you can pare down the feature set, i.e. the number of unique tokens. Try not to strip too much off the words!

# %% [markdown]
# ## Porter Stemmer
#
# The classic stemmer is the Porter stemmer which is [available in NLTK](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.porter). Others are available, too

# %%
from nltk.stem.porter import PorterStemmer

# %%
# Run this cell to see how the Porter Stemmer performs.

ps = PorterStemmer()

print 'initial number of unique tokens:', len(set(word_bag))
print 'stemmed number of unique tokens:', len({ps.stem(token) for token in word_bag})  # this uses a set comprehension

# %%
# examine how weird the tokens get

for token in word_bag:
    print ps.stem(token)
