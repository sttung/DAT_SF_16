# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv('1440041919csv.csv')

dataset
# Out:
#          #                                     INCIDENT TITLE  \
# 0     2488            20 tents was sent to Kokali Okhaldhunga
# 1     2487                                 Relief distributed
# 2     2486                                 Relief distributed
# 3     2485                                 Relief distributed
# 4     2484                                 Relief distributed
# 5     2482                                 Relief distributed
# 6     2481                                 Relief distributed
# 7     2480                                 Relief distributed
# 8     2479                          Relief distibuted by AYON
# 9     2478                                 Relief distributed
# 10    2465                  Summary of Ri VDC, Dhading - NAPA
# 11    2458  Relief distributed in Bonpale, Luitel, Western...
# 12    2456  Relief distributed in Palungtar, Nakhor 10 Wes...
# 13    2455  Relief Distributed in Golche VDC (Foods, tents...
# ...
